# %% [markdown]
# <a href="https://colab.research.google.com/github/van-dang/MRI-Cloud/blob/master/ModifySurface.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install numpy-stl

import numpy, math
from stl import mesh

# Using an existing stl file:
your_mesh = mesh.Mesh.from_file('27o_spindle19aFI.stl')

scale = 2

your_mesh.x *= scale

your_mesh.y *= scale

your_mesh.z *= scale

your_mesh.save('27o_spindle19aFI_scaled.stl')
